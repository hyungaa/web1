# %% [markdown]
# <a href="https://colab.research.google.com/github/hyungaa/web1/blob/master/ML_chapter_6_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#한글 폰트 설치하기
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 11 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 0s (44.8 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %% [markdown]
# # **1. Matplotlib**

# %% [markdown]
# **선 그래프 그리기**

# %%
from matplotlib import pyplot as plt
plt.rc('font',size='20' ,family='NanumBarunGothic') # rc를 통해 한글 폰트 설정

plt.plot(['유재석','박명수','하하'], [85, 100, 95]) #plt.plot() 메소드로 선 그래프 그리기(첫번째 인자는 x축, 두번째 인자는 y축 값)
plt.title('수학 점수') #그래프 제목 설정
plt.show() #그래프를 화면에 출력

# %% [markdown]
# **선 그래프 그리기 응용**

# %%
from matplotlib import pyplot as plt

x = ['유재석','박명수','하하','정형돈']
y_1 = [85, 100, 95, 88]
y_2 = [79, 97, 87, 92]
plt.plot(x, y_1, label='수학', color='red', linestyle='-.',marker='o') # plt.plot() 메소드로 선 그래프 그리기(첫번째 인자는 x축, 두번째 인자는 y축 값), 선 스타일(색상, 선 종류, 마커)
plt.plot(x, y_2, label='영어' ) # plt.plot() 메소드로 선 그래프 그리기(첫번째 인자는 x축, 두번째 인자는 y축 값)
plt.legend(loc='lower right') # 범례 표시(우측 하단) #upper/center/lower + left/center/right
plt.title('수학/영어 성적') # 그래프 제목 설정
plt.xlabel('이름') #X축 레이블 이름 설정
plt.ylabel('점수') #Y축 레이블 이름 설정
plt.ylim(70,105) # Y축의 범위 설정
plt.grid(True) # 그리드 출력
plt.show() # 그래프를 화면에 출력

# %% [markdown]
# **막대 그래프 그리기**

# %%
from matplotlib import pyplot as plt

x = ['유재석','박명수','하하','정형돈']
y = [90, 79, 88, 100]
plt.bar(x, y, label='미술') # plt.plot() 메소드로 선 그래프 그리기(첫번째 인자는 x축, 두번째 인자는 y축 값)
plt.legend(loc='upper left') # 범례 표시(우측 하단) #upper/center/lower + left/center/right
plt.title('미술 성적') # 그래프 제목 설정
plt.ylim(70,105) # Y축의 범위 설정
plt.show() # 그래프를 화면에 출력

# %% [markdown]
# **산점도 그리기**

# %%
from matplotlib import pyplot as plt

x = ['월','화','수','목','금','토','일']
y = [1.3, 2.5, 1.1, 2.1, 1.7, 2.4, 2.7]
plt.title('요일별 평균 운동시간') # 그래프 제목 설정
plt.scatter(x,y) #산포 그래프 그리기
plt.show() # 그래프를 화면에 출력

# %% [markdown]
# **파이 그래프 그리기**

# %%
import matplotlib.pyplot as plt

answer = ['그렇다', '보통이다','그렇지 않다','잘 모르겠다']
data = [53.1, 27.3, 12.5, 7.1]
plt.pie(data, labels=answer, autopct ='%0.1f%%') # 파이 그래프 생성(소수점 1자리까지 보이도록 설정)
plt.show() # 그래프를 화면에 출력

# %% [markdown]
# **다수의 그래프 그리기**

# %%
import matplotlib.pyplot as plt

x = ['월','화','수','목 ','금','토','일']
y1 = [2.5, 1.5, 0.7, 2.7, 2.3, 2.9, 1.2]
y2 = [1.3, 2.5, 1.1, 2.1, 1.7, 2.4, 2.7]
y3 = [2.6, 1.4, 4.1, 1.1, 2.4, 1.2, 3.1]
y4 = [2.4, 3.1, 2.6, 1.5, 2.9, 1.9, 1.6]

fig, axs = plt.subplots(nrows=2, 
                        ncols=2, figsize=(12, 7), sharex=True, sharey=True) # (12,7) 크기의 2x2 subplot 선언

final = axs[0][0] # subplot(0,0)을 final에 대입
final.scatter(x, y1) #산점도 그리기
final.set_title('1월') # 그래프 제목 설정

final = axs[0][1] # subplot(0,1)을 final에 대입
final.bar(x, y2, color='green') #막대 그래프 그리기, 그래프 색상 : 녹색
final.set_title('2월') # 그래프 제목 설정

final = axs[1][0] # subplot(1,0)을 final에 대입
final.bar(x, y3, width=0.3, color='blue') #막대 그래프 그리기, 그래프 너비 : 0.3, 그래프 색상 : 파랑
final.set_title('3월') # 그래프 제목 설정

final = axs[1][1] # subplot(1,1)을 final에 대입
final.plot(x, y4, color='red', linestyle='--', marker='x') #선 그래프 그리기, 스타일 지정, 마커 지정
final.set_title('4월') # 그래프 제목 설정

fig.suptitle('요일별 평균 운동시간') # fig 그래프 제목 설정
plt.show() # 그래프를 화면에 출력

# %% [markdown]
# **pandas를 활용한 그래프 그리기(선 그래프)**

# %%
import numpy as np
import pandas as pd

sr = pd.Series(np.random.rand(10), index=np.arange(10, 110, 10)) #Series 활용 그래프, random_sample : [0.0, 1.0) 범위의 임의의 실수를 반환
df = pd.DataFrame(np.random.rand(10, 4), #DadaFrame 활용 그래프, row : 10, col:4 
                  columns=['A', 'B', 'C', 'D'], # column 설정 "A, B, C, D"
                  index=np.arange(10, 110, 10)) # x축 인덱스 설정(10~110, 간격: 10)
print(df.head())
sr.plot(title="연령별 확진자 비율(%)") # pandas series를 활용한 그래프 그리기
df.plot(title="지역별/연령별 확진자 비율(%)") # pandas dataframe을 활용한 그래프 그리기
# Out:
#            A         B         C         D
# 10  0.576133  0.258731  0.598163  0.217915
# 20  0.569910  0.077738  0.730913  0.769842
# 30  0.648826  0.689416  0.943617  0.741482
# 40  0.373283  0.995138  0.975093  0.740939
# 50  0.123061  0.839792  0.705373  0.374983

# %% [markdown]
# **pandas를 활용한 그래프 그리기(바 그래프)**

# %%
import numpy as np
import pandas as pd

# pandas serise를 활용하여 바 그래프 생성
s_bar = pd.Series(np.random.rand(4), # 4개의 난수 생성
                  index=list("ABCD")) # index 설정("A,B,C,D")
s_bar.plot(kind='bar', title="지역별 환자 비율(%)") #pandas series를 활용한 바 그래프 그리기(kind는 그래프 종류, title은 제목)

df_bar = pd.DataFrame(np.random.rand(3, 4), # 3x4 난수 생성
                   index=["한국", "미국", "일본"], # index 설정
                   columns=["1월", "2월", "3월", "4월"]) # column 설정

df_bar.plot(kind='bar', title="국가별/월별 환자 증가 비율") # dataframe을 활용하여 바 그래프 그리기(kind는 그래프 종류, title은 제목)

# %% [markdown]
# **pandas를 활용한 그래프 그리기(히스토그램)**

# %%
import numpy as np
import pandas as pd

s_hist = pd.Series(np.random.randn(100)) # 가우시안 표준 정규분포 난수 선언
s_hist.hist(bins=10) #bins x축 구간 개수 설정
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # **2. Seaborn**

# %% [markdown]
# **distplot 활용하기**

# %%
import seaborn as sns # 데이터 시각화 라이브러리

iris = sns.load_dataset("iris") # seaborn에서 제공하는 iris 데이터 로드
sns.distplot(iris["sepal_width"], #displot을 활용하여 그래프 생성
             hist=True, # 히스토그램 그래프 표시
             kde=True, # 밀집도 그래프 표시
             rug=True) # 선 그래프 표시

# %% [markdown]
# **countplot 활용하기**

# %%
import seaborn as sns

titanic = sns.load_dataset("titanic") # titanic 데이터 로드

sns.countplot(x="class", data=titanic) # coutplot을 활용하여 titanic 데이터에서 각 class 수를 count하여 그래프로 그림
#sns.countplot(x="class", hue="who",data=titanic)
#sns.countplot(y="class", hue="who",data=titanic)

# %% [markdown]
# **relplot 활용하기**

# %%
import seaborn as sns

tips = sns.load_dataset("tips") # tips 데이터 로드 
#sns.relplot(x="total_bill",y="tip", data=tips)
sns.relplot(x="total_bill",y="tip", hue="smoker",data=tips,  # relplot을 활용하여 line plot 그리기
            kind="line") # x는 x축 제목, y는 y축 제목, hue는 hue semantic 제목, data는 그래프에 들어가는 데이터, kind는 그래프 종류
sns.relplot(x="total_bill",y="tip", hue="smoker", col="time",data=tips) # replot을 활용하여 time을 기준으로 scatter plot 그리기
#sns.relplot(x="total_bill",y="tip", hue="smoker", col="time", row="sex",data=tips)

# %% [markdown]
# **catplot 활용하기**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips") # catplot을 활용하여 범주형 변수와 수(치)형 변수간 관계 시각화
sns.catplot(x="day",y="total_bill", data=tips)  # x는 x축 제목, y는 y축 제목, data는 그래프에 들어가는 데이터
sns.catplot(x="day",y="total_bill", hue="smoker", kind="bar",data=tips) # x는 x축 제목, y는 y축 제목, hue는 hue semantic 제목, data는 그래프에 들어가는 데이터, kind는 그래프 종류
sns.catplot(x="day", y="total_bill", hue="smoker", kind="violin", data=tips) # x는 x축 제목, y는 y축 제목, hue는 hue semantic 제목, data는 그래프에 들어가는 데이터, kind는 그래프 종류
plt.figure(figsize=(8,6)) # figure 크기를 8,6으로 설정

# %% [markdown]
# **boxplot 활용하기**

# %%
import seaborn as sns

tips = sns.load_dataset("tips") # tips 데이터 로드
sns.boxplot(x="day", y="total_bill", data=tips) # boxplot을 활용하여 데이터 집합의 범위와 중앙값 시각화, x는 x축 제목, y는 y축 제목, data는 그래프에 들어가는 데이터
#ax = sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="Set3")
#ax = sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")

# %% [markdown]
# **jointplot 활용하기**

# %%
import seaborn as sns


tips = sns.load_dataset("tips") # tips 데이터 로드
sns.jointplot(x="total_bill", y="tip", data=tips) # jointplot을 활용하여 scatter 플롯과 각 축에 대한 히스토그램 시각화, x는 x축 제목, y는 y축 제목, data는 그래프에 들어가는 데이터
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex") # x는 x축 제목, y는 y축 제목, data는 그래프에 들어가는 데이터, kind는 joint plot 종류(hex, kde, reg)

#tips.head()

# %% [markdown]
#  **pairplot 활용하기**

# %%
import seaborn as sns


iris = sns.load_dataset("iris") # iris 데이터 로드
sns.pairplot(iris) # pairplot을 활용하여 각 데이터 조합에 대한 히스토그램과 분포도 시각화
#sns.pairplot(data=iris, hue="species")
sns.pairplot(iris, vars=["sepal_length", "sepal_width"]) # "sepal_length", "sepal_width" 두 변수에 대한 pairplot 그리기

# %% [markdown]
# **heatmap 활용하기**

# %%
import seaborn as sns


flights = sns.load_dataset('flights') # flights 데이터 로드
flight = flights.pivot('month', 'year', 'passengers') # month, year 데이터에 대한 passengers 집계 
sns.heatmap(flight, annot=True, fmt="d") # pivot으로 집계된 데이터(flight)를 heatmap으로 시각화, annot은 집계 값(passengers) 표시 여부, fmt는 정수형 포맷

# %% [markdown]
# # **3. Scikit-learn을 활용한 첫 번째 머신러닝**

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score
import seaborn as sns

iris = load_iris() # 붓꽃 데이터 셋 로딩
#print(iris)

iris_data = iris.data # iris.data : Iris 데이터셋에서 feature 데이터
iris_label = iris.target # iris.target : Iris 데이터셋에서 레이블 데이터
#print('iris data 값: ', iris_data[:5])
#print('iris target의 값: ', iris_label)

# %%
iris_df = pd.DataFrame(data=iris_data, columns=iris.feature_names) # Iris 데이터셋을 DataFrame으로 변환
iris_df ['label'] = iris.target # iris_df에 iris target data 추가
#iris_df.head()

sns.pairplot(iris_df, x_vars=["sepal length (cm)"],  # 첫 번째 인자: 데이터, x_vars: x 축 변수 설정
             y_vars=["sepal width (cm)"], hue="label", height=5) # y_vars: y축 변수 설정, hue: label 제목 설정, height: plot 크기 설정

# %%
X_train, X_test, y_train, y_test = train_test_split(iris_data, iris_label, test_size=0.2) # 데이터셋 분리

dt_clf = DecisionTreeClassifier() # DecisionTreeClassifier 객체 생성
knn_clf = KNeighborsClassifier() # KNeighborsClassifier 객체 생성

dt_clf.fit(X_train, y_train) # 모델 학습 수행
knn_clf.fit(X_train, y_train) # 모델 학습 수행

y1_pred = dt_clf.predict(X_test) # 예측
y2_pred = knn_clf.predict(X_test) # 예측

print('DecisionTree 예측정확도 : {0:.4f}'.format(accuracy_score(y_test, y1_pred))) # 평가
print('k-NN 예측정확도 : {0: .4f}'.format(accuracy_score(y_test, y2_pred))) # 평가

# %% [markdown]
# **이번 강의도 수고 많으셨습니다. 감사합니다.**
